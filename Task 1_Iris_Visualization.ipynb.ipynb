# %% [markdown]
# # Task 1: Exploring and Visualizing a Simple Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Iris dataset
df = sns.load_dataset('iris')
print(df.shape)      #rows & columns
print(df.columns)    # Column names
print(df.head())
# Out:
# (150, 5)
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='sepal_length', y='petal_length', hue='species')
plt.title('Sepal vs Petal Length by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.show()

# %%
plt.figure(figsize=(10,8))
features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)
    sns.histplot(data=df, x=feature, bins=15, kde=True, color='skyblue')
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df[features])
plt.title('Boxplot of Iris Features')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='species', y='petal_length', data=df)
plt.title('Petal Length by Species')
plt.show()

# %% [markdown]
# # Summary

# %% [markdown]
# In this task, the Iris dataset was explored using pandas, matplotlib, and seaborn to understand the structure and distribution of the data. Basic inspections using .shape, .columns, and .head() provided insights into the dataset’s dimensions and features. Visualizations including scatter plots, histograms, and boxplots were created to reveal relationships between sepal and petal dimensions and to identify feature distributions and outliers. These visual tools made it easier to distinguish between the three flower species based on their measurements, laying the groundwork for future classification models.
